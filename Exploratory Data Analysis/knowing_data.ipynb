# %% [markdown]
# # Exploratory Data Analysis
#
# ## Cntext: knowing a litte about dataset

# %% [markdown]
# # Import librarys
# - *import numpy as np*
# - *import pandas as pd*

# %%
import numpy as np
import pandas as pd

# %%
dataset_one = pd.read_csv("datasets/restaurants_cuisine_ratings/Cuisine_rating.csv")

# %%
# Display 5 first line
dataset_one.head()
# Out:
#    User ID  Area code            Location  Gender   YOB Marital Status  \
# 0        1        153  Upper East Side,NY  Female  2006         Single
# 1        2        123       St. George,NY  Female  1991        Married
# 2        3        122  Upper West Side,NY    Male  1977         Single
# 3        4        153  Upper East Side,NY  Female  1956        Married
# 4        5        129     Central Park,NY    Male  1997         Single
#
#        Activity  Budget  Cuisines  Alcohol     Smoker  Food Rating  \
# 0  Professional       3  Japanese     Never     Never            5
# 1       Student       3    Indian     Never  Socially            1
# 2       Student       5   Seafood     Often     Often            5
# 3  Professional       5  Japanese     Never  Socially            3
# 4       Student       4  Filipino  Socially     Never            2
#
#    Service Rating  Overall Rating Often A S
# 0               4             4.5        No
# 1               1             1.0        No
# ...

# %%
dataset_one.info("")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   User ID         200 non-null    int64
#  1   Area code       200 non-null    int64
#  2   Location        200 non-null    object
#  3   Gender          200 non-null    object
#  4   YOB             200 non-null    int64
#  5   Marital Status  200 non-null    object
#  6   Activity        200 non-null    object
#  7   Budget          200 non-null    int64
#  8   Cuisines        200 non-null    object
#  9   Alcohol         200 non-null    object
#  10  Smoker          200 non-null    object
#  11  Food Rating     200 non-null    int64
#  12  Service Rating  200 non-null    int64
#  13  Overall Rating  200 non-null    float64
#  14  Often A S       200 non-null    object
# dtypes: float64(1), int64(6), object(8)
# memory usage: 23.6+ KB

# %%
# Count quanity cuisines by row
dataset_one['Cuisines'].value_counts()
# Out:
# Cuisines
# Japanese    36
# Filipino    34
# French      34
# Indian      32
# Chinese     24
# Seafood     22
# Italian     18
# Name: count, dtype: int64

# %%
# Filter by japanese Cuisines
dataset_one[dataset_one["Cuisines"] == 'Japanese']
# Out:
#      User ID  Area code            Location  Gender   YOB Marital Status  \
# 0          1        153  Upper East Side,NY  Female  2006         Single
# 3          4        153  Upper East Side,NY  Female  1956        Married
# 17        18        153  Upper East Side,NY    Male  2004         Single
# 25        26        123       St. George,NY    Male  1969         Single
# 34        35        129     Central Park,NY    Male  2001       Divorced
# 35        36        107        Riverdale,NY    Male  1998         Single
# 36        37        154     Market City, NY    Male  2006         Single
# 42        43        123       St. George,NY    Male  1985        Married
# 49        50        107        Riverdale,NY  Female  1974        Married
# 50        51        107        Riverdale,NY  Female  2007         Single
# 58        59        123       St. George,NY    Male  1964         Single
# 60        61        129     Central Park,NY  Female  2003         Single
# ...

# %%
# Filter by Filipino cuisine
dataset_one[dataset_one['Cuisines']== 'Filipino']
# Out:
#      User ID  Area code            Location  Gender   YOB Marital Status  \
# 4          5        129     Central Park,NY    Male  1997         Single
# 7          8        153  Upper East Side,NY  Female  2003         Single
# 14        15        107        Riverdale,NY    Male  1956        Married
# 18        19        129     Central Park,NY    Male  2001         Single
# 39        40        123       St. George,NY    Male  1986         Single
# 41        42        154     Market City, NY  Female  1967         Single
# 53        54        123       St. George,NY    Male  1989         Single
# 54        55        107        Riverdale,NY  Female  1958         Single
# 55        56        122  Upper West Side,NY  Female  1991         Single
# 57        58        129     Central Park,ny    Male  1962        Married
# 71        72        123       St. George,NY    Male  2006         Single
# 74        75        123       St. George,NY    Male  2002         Single
# ...

# %%
# Filter by French Cuisine
dataset_one[dataset_one['Cuisines'] == 'French']
# Out:
#      User ID  Area code            Location  Gender   YOB Marital Status  \
# 10        11        123       St. George,NY  Female  1975        Married
# 15        16        153  Upper East Side,NY  Female  1956        Married
# 28        29        154     Market City, NY  Female  1977        Married
# 37        38        123       St. George,NY  Female  1990         Single
# 38        39        153  Upper East Side,NY    Male  1987        Married
# 43        44        129     Central Park,NY    Male  2000         Single
# 46        47        129     Central Park,ny    Male  1976         Single
# 65        66        107        Riverdale,NY    Male  1975        Married
# 68        69        111      China Town, NY    Male  1961        Married
# 80        81        154     Market City, NY  Female  1974        Married
# 82        83        122  Upper West Side,NY    Male  1996        Married
# 87        88        129     Central Park,NY  Female  2007         Single
# ...

# %%
# media das avaliações de notas for Japanese. 
dataset_one[dataset_one['Cuisines'] == 'Japanese']['Overall Rating'].mean()
# Out:
# 3.5972222222222223

# %%
# media das avaliações de notas for Filipino. 
dataset_one[dataset_one['Cuisines'] == 'Filipino']['Overall Rating'].mean()
# Out:
# 3.0441176470588234

# %%
# media das avaliações de notas for Filipino. 
dataset_one[dataset_one['Cuisines'] == 'French']['Overall Rating'].mean()
# Out:
# 3.1029411764705883

# %%
# media das avaliações de notas for Indian.
dataset_one[dataset_one['Cuisines'] == 'Indian']['Overall Rating'].mean()
# Out:
# 3.171875

# %%
# media das avaliações de notas for Chinese.
dataset_one[dataset_one['Cuisines'] == 'Chinese']['Overall Rating'].mean()
# Out:
# 3.2708333333333335

# %%
#  media das avaliações de notas for Seafood
dataset_one[dataset_one['Cuisines'] == 'Seafood']['Overall Rating'].mean()
# Out:
# 3.1363636363636362

# %%
#  media das avaliações de notas for Italian
dataset_one[dataset_one['Cuisines'] == 'Italian']['Overall Rating'].mean()
# Out:
# 3.1944444444444446
