# %% [markdown]
# # Exploratory Data Analysis
# ## Understanding how variables relate
# ### Import librarys
# - *import numpy as np*
# - *import pandas as pd*

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_penguins = sns.load_dataset("penguins")

# %%
# df_penguins.info()
# df_penguins['sex']
# Remove NaN with function 'isna()'
# df_penguins.loc[df_penguins['sex'].isna(), 'sex'] = ""
# df_penguins.loc[df_penguins['island'].isna(), "island"] = "" 
# df_penguins.loc[df_penguins['flipper_length_mm'].isna(), 'flipper_length_mm'] = ""
# salto_Sp_houses.loc[salto_Sp_houses['vagas_casa'] == '--', 'vagas_casa'] = 0

# Cast for float
# Step 1: Replace empty strings with NaN
#df_penguins.loc[df_penguins['flipper_length_mm'] == "", 'flipper_length_mm'] = np.nan
# Step 2: Convert to nullable Float64 type
#df_penguins['flipper_length_mm'] = df_penguins['flipper_length_mm'].astype(pd.Float64Dtype())
# df_penguins.loc[df_penguins['flipper_length_mm'].isna(), 'flipper_length_mm'] = ""

# %%
df_penguins.info()
# df_penguins.head(50)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
df_penguins['species'].value_counts()
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %%
df_penguins_numeric = df_penguins.drop(columns = ['species','island','sex'])

# %%
# df_penguins_numeric.info()
df_penguins_numeric.corr()
# Out:
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm           1.000000      -0.235053           0.656181
# bill_depth_mm           -0.235053       1.000000          -0.583851
# flipper_length_mm        0.656181      -0.583851           1.000000
# body_mass_g              0.595110      -0.471916           0.871202
#
#                    body_mass_g
# bill_length_mm        0.595110
# bill_depth_mm        -0.471916
# flipper_length_mm     0.871202
# body_mass_g           1.000000

# %%
for col in df_penguins.drop(columns= ['species','island','sex']):
    sns.barplot(data= df_penguins, x='species', y=col, errorbar=('ci', 90))
    plt.show()
